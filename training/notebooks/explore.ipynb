# %%
import pandas as pd
df = pd.read_csv('../data/preprocessed/crypto_data_proc.csv')

# %%
df.head()
# Out:
#    time_idx  token  open_log  high_log   low_log  close_log  volume_log  \
# 0         0  1INCH  2.558157 -0.138144  2.409150  -0.030149   16.926395
# 1         1  1INCH -0.026367  0.070677  0.059331   0.045938   16.874238
# 2         2  1INCH  0.045316 -0.021816  0.043149  -0.003933   16.677244
# 3         3  1INCH -0.008165 -0.026874  0.038948   0.008800   16.110003
# 4         4  1INCH  0.009949  0.079119  0.027554   0.048203   16.923341
#
#    btc_close_log  eth_close_log  eth_btc_ratio  hour_sin      hour_cos  \
# 0       0.001111       0.007636       0.025986  1.000000  6.123234e-17
# 1       0.001031      -0.001646       0.025916  0.965926 -2.588190e-01
# 2       0.001167       0.006651       0.026059  0.866025 -5.000000e-01
# 3       0.010799       0.010399       0.026049  0.707107 -7.071068e-01
# 4       0.001701       0.003810       0.026104  0.500000 -8.660254e-01
#
#    norm_day_sin  norm_day_cos  weekday_sin  weekday_cos     month_sin  \
# ...
